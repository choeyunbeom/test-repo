# %%
import pandas as pd
import numpy as np
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
df = pd.read_csv("./data/train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.drop(["Alley", "MasVnrType", "FireplaceQu", "PoolQC", "Fence", "MiscFeature"], axis = 1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
for i in df.columns:
    if df[i].dtype == "int64":
        if df[i].nunique() < 30:
            print(i,":",df[i].unique())
            print(i,":", df[i].nunique())
            print("-" * 100)
            df[i] = df[i].astype("category")
    elif df[i].dtype == "float64":
        if df[i].nunique() < 30:
            print(i,":",df[i].unique())
            print(i,":", df[i].nunique())
            print("-" * 100)
            df[i] = df[i].astype("category")
    else:
        print(i,":",df[i].unique())
        print(i,":", df[i].nunique())
        print("-" * 100)
# Out:
# MSSubClass : [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
# MSSubClass : 15
# ----------------------------------------------------------------------------------------------------
# MSZoning : ['RL' 'RM' 'C (all)' 'FV' 'RH']
# MSZoning : 5
# ----------------------------------------------------------------------------------------------------
# Street : ['Pave' 'Grvl']
# Street : 2
# ----------------------------------------------------------------------------------------------------
# LotShape : ['Reg' 'IR1' 'IR2' 'IR3']
# LotShape : 4
# ----------------------------------------------------------------------------------------------------
# LandContour : ['Lvl' 'Bnk' 'Low' 'HLS']
# LandContour : 4
# ----------------------------------------------------------------------------------------------------
# Utilities : ['AllPub' 'NoSeWa']
# Utilities : 2
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# - MSSubClass, MoSold, YrSold 는 범주형,,,

# %%
for i in df.columns:
    if df[i].dtype == "object":
        most_freq = df[i].value_counts().idxmax()
        df[i] = df[i].fillna(most_freq)
    elif df[i].dtype == "category":
        most_freq = df[i].value_counts().idxmax()
        df[i] = df[i].fillna(most_freq)  
    else:
        df[i] = df[i].fillna(0)

# %%
df['Id'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# - 카테고리 NaN - 최빈값
# - 수치 NaN - 0

# %%
df.head()
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1         60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2         20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3         60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4         70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5         60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   category
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   category
# ...

# %%
df['LotFrontage'].astype('int')
# Out:
# 0       65
# 1       80
# 2       68
# 3       60
# 4       84
#         ..
# 1455    62
# 1456    85
# 1457    66
# 1458    68
# 1459    75
# Name: LotFrontage, Length: 1460, dtype: int32

# %%
corr = df[df.describe().columns].corr()
corr
# Out:
#                      Id  LotFrontage   LotArea  YearBuilt  YearRemodAdd  \
# Id             1.000000    -0.019761 -0.033226  -0.012713     -0.021998
# LotFrontage   -0.019761     1.000000  0.100739   0.036853      0.078686
# LotArea       -0.033226     0.100739  1.000000   0.014228      0.013788
# YearBuilt     -0.012713     0.036853  0.014228   1.000000      0.592855
# YearRemodAdd  -0.021998     0.078686  0.013788   0.592855      1.000000
# MasVnrArea    -0.051071     0.105010  0.103321   0.311600      0.176529
# BsmtFinSF1    -0.005024     0.076670  0.214103   0.249503      0.128451
# BsmtFinSF2    -0.005968    -0.009312  0.111170  -0.049107     -0.067759
# BsmtUnfSF     -0.007940     0.160829 -0.002618   0.149040      0.181133
# TotalBsmtSF   -0.015415     0.238274  0.260833   0.391452      0.291066
# 1stFlrSF       0.010496     0.245181  0.299475   0.281986      0.240379
# 2ndFlrSF       0.005590     0.042549  0.050986   0.010308      0.140024
# ...

# %%
try:
    for i in df.columns:
        df[i] = df[i].astype('int')
except:
    pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int32
#  1   MSSubClass     1460 non-null   int32
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   category
# ...

# %%
list = ['MSSubClass', 'MoSold', 'YrSold']
for i in list:
    df[i] = df[i].astype('object')

# %%
for i in df.columns:
    le = LabelEncoder()
    if df[i].dtype == "category":
        df[i] = le.fit_transform(df[i])
else:
    pass

# %%
df.dtypes =="category"
# Out:
# Id               False
# MSSubClass       False
# MSZoning         False
# LotFrontage      False
# LotArea          False
#                  ...
# MoSold           False
# YrSold           False
# SaleType         False
# SaleCondition    False
# SalePrice        False
# Length: 75, dtype: bool

# %%
df.head()
# Out:
#    Id MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1         60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2         20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3         60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4         70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5         60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType  \
# 0    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 1    AllPub       FR2       Gtl      Veenker      Feedr       Norm     1Fam
# 2    AllPub    Inside       Gtl      CollgCr       Norm       Norm     1Fam
# 3    AllPub    Corner       Gtl      Crawfor       Norm       Norm     1Fam
# 4    AllPub       FR2       Gtl      NoRidge       Norm       Norm     1Fam
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int32
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
for i in df.columns:
    if df[i].dtype == "int64":
        if df[i].nunique() < 30:
            print(i,":",df[i].unique())
            print(i,":", df[i].nunique())
            print("-" * 100)
            
    elif df[i].dtype == "float64":
        if df[i].nunique() < 30:
            print(i,":",df[i].unique())
            print(i,":", df[i].nunique())
            print("-" * 100)
            
    else:
        print(i,":",df[i].unique())
        print(i,":", df[i].nunique())
        print("-" * 100)
# Out:
# Id : [   1    2    3 ... 1458 1459 1460]
# Id : 1460
# ----------------------------------------------------------------------------------------------------
# MSSubClass : [60 20 70 50 190 45 90 120 30 85 80 160 75 180 40]
# MSSubClass : 15
# ----------------------------------------------------------------------------------------------------
# MSZoning : ['RL' 'RM' 'C (all)' 'FV' 'RH']
# MSZoning : 5
# ----------------------------------------------------------------------------------------------------
# Street : ['Pave' 'Grvl']
# Street : 2
# ----------------------------------------------------------------------------------------------------
# LotShape : ['Reg' 'IR1' 'IR2' 'IR3']
# LotShape : 4
# ----------------------------------------------------------------------------------------------------
# LandContour : ['Lvl' 'Bnk' 'Low' 'HLS']
# LandContour : 4
# ----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# - 'OverallQual', 'OverallCond', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageQual', 'GarageCond', 'PoolArea'

# %%
list1 = ['OverallQual', 'OverallCond', 'ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond', 'HeatingQC', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageQual', 'GarageCond', 'PoolArea']
for i in list1:
    le = LabelEncoder()
    df[i] = le.fit_transform(df[i])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int32
#  1   MSSubClass     1460 non-null   object
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
try:
    for i in df.columns:
        df[i] = df[i].astype("int")
except:
    pass

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int32
#  1   MSSubClass     1460 non-null   int32
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
df.drop("Id", axis = 1, inplace = True)

# %%
corr = df[df.describe().columns].corr()
corr
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.215023 -0.139781     0.032628    -0.059316
# LotFrontage     -0.215023     1.000000  0.100739     0.176561    -0.053457
# LotArea         -0.139781     0.100739  1.000000     0.105806    -0.005636
# OverallQual      0.032628     0.176561  0.105806     1.000000    -0.091932
# OverallCond     -0.059316    -0.053457 -0.005636    -0.091932     1.000000
# YearBuilt        0.027850     0.036853  0.014228     0.572323    -0.375983
# YearRemodAdd     0.040581     0.078686  0.013788     0.550684     0.073741
# MasVnrArea       0.023573     0.105010  0.103321     0.407252    -0.125694
# ExterQual       -0.017161    -0.152801 -0.057275    -0.634319     0.169186
# ExterCond       -0.003254     0.045593  0.015160     0.138581    -0.227407
# BsmtQual        -0.041065    -0.160555 -0.065150    -0.600561     0.233461
# ...

# %%
corr["SalePrice"][np.abs(corr["SalePrice"]) > 0.4].index
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'ExterQual',
#        'BsmtQual', 'TotalBsmtSF', 'HeatingQC', '1stFlrSF', 'GrLivArea',
#        'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'SalePrice'],
#       dtype='object')

# %%
sns.pairplot(df[['OverallQual', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'ExterQual',
       'BsmtQual', 'TotalBsmtSF', 'HeatingQC', '1stFlrSF', 'GrLivArea',
       'FullBath', 'KitchenQual', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
       'GarageArea', 'SalePrice']])
